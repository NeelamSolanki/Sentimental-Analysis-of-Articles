# %%
with open ("StopWords/StopWords_Currencies.txt","r") as f:
    a=f.read()
    #a=a.split("|")
    a=a.replace("|","")
    a=a.replace("\n","")
a
# Out:
# 'AFGHANI   Afghanistan ARIARY  Madagascar BAHT  Thailand BALBOA  Panama BIRR  Ethiopia BOLIVAR  Venezuela BOLIVIANO   Bolivia CEDI  Ghana COLON   Costa Rica CÓRDOBA   Nicaragua DALASI  Gambia DENAR  Macedonia (Former Yug. Rep.) DINAR  Algeria DIRHAM   Morocco DOBRA  São Tom and Príncipe DONG  Vietnam DRAM  Armenia ESCUDO   Cape Verde EURO   Belgium FLORIN  Aruba FORINT  Hungary GOURDE  Haiti GUARANI  Paraguay GULDEN  Netherlands Antilles HRYVNIA   Ukraine KINA  Papua New Guinea KIP  Laos KONVERTIBILNA MARKA   Bosnia-Herzegovina KORUNA   Czech Republic KRONA  Sweden KRONE  Denmark KROON  Estonia KUNA  Croatia KWACHA  Zambia KWANZA  Angola KYAT  Myanmar LARI  Georgia LATS  Latvia LEK  Albania LEMPIRA  Honduras LEONE  Sierra Leone LEU  Romania LEV  Bulgaria LILANGENI   Swaziland LIRA  Lebanon LITAS  Lithuania LOTI  Lesotho MANAT  Azerbaijan METICAL  Mozambique NAIRA  Nigeria NAKFA  Eritrea NEW LIRA  Turkey NEW SHEQEL   Israel NGULTRUM   Bhutan NUEVO SOL  Peru OUGUIYA   Mauritania PATACA
# ...

# %%
import os
stop_words = []
for file in os.listdir("StopWords"):
    with open (f"StopWords/{file}","r") as f:
        a=f.read()      
        a=a.replace("|"," ")
        a=a.replace("\n"," ")
        a=a.split(" ")
    
    stop_words.extend(list(a))
stop_words
# Out:
# ['ERNST',
#  'YOUNG',
#  'DELOITTE',
#  'TOUCHE',
#  'KPMG',
#  'PRICEWATERHOUSECOOPERS',
#  'PRICEWATERHOUSE',
#  'COOPERS',
#  '',
#  'AFGHANI',
#  '',
#  '',
#  '',
#  'Afghanistan',
#  '',
#  'ARIARY',
#  '',
#  '',
#  'Madagascar',
#  '',
#  'BAHT',
#  '',
#  '',
#  'Thailand',
#  '',
#  'BALBOA',
#  '',
#  '',
#  'Panama',
#  '',
#  'BIRR',
#  '',
#  '',
#  'Ethiopia',
#  '',
#  'BOLIVAR',
#  '',
#  '',
#  'Venezuela',
#  '',
#  'BOLIVIANO',
#  '',
#  '',
#  '',
#  'Bolivia',
#  '',
#  'CEDI',
#  '',
#  '',
#  'Ghana',
#  '',
#  'COLON',
#  '',
#  '',
#  '',
#  'Costa',
#  'Rica',
#  '',
#  'CÓRDOBA',
#  '',
#  '',
#  '',
#  'Nicaragua',
#  '',
#  'DALASI',
#  '',
#  '',
#  'Gambia',
#  '',
#  'DENAR',
#  '',
#  '',
#  'Macedonia',
#  '(Former',
#  'Yug.',
#  'Rep.)',
#  '',
#  'DINAR',
#  '',
#  '',
#  'Algeria',
#  '',
#  'DIRHAM',
#  '',
#  '',
#  '',
#  'Morocco',
#  '',
#  'DOBRA',
#  '',
#  '',
#  'São',
#  'Tom',
#  'and',
#  'Príncipe',
#  '',
#  'DONG',
#  '',
#  '',
# ...

# %%
new_stop_words=[]
for i in stop_words:
    if(i!=""):
        new_stop_words.append(i)

new_stop_words
# Out:
# ['ERNST',
#  'YOUNG',
#  'DELOITTE',
#  'TOUCHE',
#  'KPMG',
#  'PRICEWATERHOUSECOOPERS',
#  'PRICEWATERHOUSE',
#  'COOPERS',
#  'AFGHANI',
#  'Afghanistan',
#  'ARIARY',
#  'Madagascar',
#  'BAHT',
#  'Thailand',
#  'BALBOA',
#  'Panama',
#  'BIRR',
#  'Ethiopia',
#  'BOLIVAR',
#  'Venezuela',
#  'BOLIVIANO',
#  'Bolivia',
#  'CEDI',
#  'Ghana',
#  'COLON',
#  'Costa',
#  'Rica',
#  'CÓRDOBA',
#  'Nicaragua',
#  'DALASI',
#  'Gambia',
#  'DENAR',
#  'Macedonia',
#  '(Former',
#  'Yug.',
#  'Rep.)',
#  'DINAR',
#  'Algeria',
#  'DIRHAM',
#  'Morocco',
#  'DOBRA',
#  'São',
#  'Tom',
#  'and',
#  'Príncipe',
#  'DONG',
#  'Vietnam',
#  'DRAM',
#  'Armenia',
#  'ESCUDO',
#  'Cape',
#  'Verde',
#  'EURO',
#  'Belgium',
#  'FLORIN',
#  'Aruba',
#  'FORINT',
#  'Hungary',
#  'GOURDE',
#  'Haiti',
#  'GUARANI',
#  'Paraguay',
#  'GULDEN',
#  'Netherlands',
#  'Antilles',
#  'HRYVNIA',
#  'Ukraine',
#  'KINA',
#  'Papua',
#  'New',
#  'Guinea',
#  'KIP',
#  'Laos',
#  'KONVERTIBILNA',
# ...

# %%
with open ("MasterDictionary/positive-words.txt","r") as f:
    poitivewords=f.read()
    poitivewords=poitivewords.split("\n")

poitivewords
# Out:
# ['a+',
#  'abound',
#  'abounds',
#  'abundance',
#  'abundant',
#  'accessable',
#  'accessible',
#  'acclaim',
#  'acclaimed',
#  'acclamation',
#  'accolade',
#  'accolades',
#  'accommodative',
#  'accomodative',
#  'accomplish',
#  'accomplished',
#  'accomplishment',
#  'accomplishments',
#  'accurate',
#  'accurately',
#  'achievable',
#  'achievement',
#  'achievements',
#  'achievible',
#  'acumen',
#  'adaptable',
#  'adaptive',
#  'adequate',
#  'adjustable',
#  'admirable',
#  'admirably',
#  'admiration',
#  'admire',
#  'admirer',
#  'admiring',
#  'admiringly',
#  'adorable',
#  'adore',
#  'adored',
#  'adorer',
#  'adoring',
#  'adoringly',
#  'adroit',
#  'adroitly',
#  'adulate',
#  'adulation',
#  'adulatory',
#  'advanced',
#  'advantage',
#  'advantageous',
#  'advantageously',
#  'advantages',
#  'adventuresome',
#  'adventurous',
#  'advocate',
#  'advocated',
#  'advocates',
#  'affability',
#  'affable',
#  'affably',
#  'affectation',
#  'affection',
# ...

# %%
with open ("MasterDictionary/negative-words.txt","r") as f:
    negativewords=f.read()
    negativewords=negativewords.split("\n")

negativewords
# Out:
# ['2-faced',
#  '2-faces',
#  'abnormal',
#  'abolish',
#  'abominable',
#  'abominably',
#  'abominate',
#  'abomination',
#  'abort',
#  'aborted',
#  'aborts',
#  'abrade',
#  'abrasive',
#  'abrupt',
#  'abruptly',
#  'abscond',
#  'absence',
#  'absent-minded',
#  'absentee',
#  'absurd',
#  'absurdity',
#  'absurdly',
#  'absurdness',
#  'abuse',
#  'abused',
#  'abuses',
#  'abusive',
#  'abysmal',
#  'abysmally',
#  'abyss',
#  'accidental',
#  'accost',
#  'accursed',
#  'accusation',
#  'accusations',
#  'accuse',
#  'accuses',
#  'accusing',
#  'accusingly',
#  'acerbate',
#  'acerbic',
#  'acerbically',
#  'ache',
#  'ached',
#  'aches',
#  'achey',
#  'aching',
#  'acrid',
#  'acridly',
#  'acridness',
#  'acrimonious',
#  'acrimoniously',
#  'acrimony',
#  'adamant',
#  'adamantly',
#  'addict',
#  'addicted',
#  'addicting',
#  'addicts',
#  'admonish',
#  'admonisher',
#  'admonishingly',
#  'admonishment',
#  'admonition',
#  'adulterate',
#  'adulterated',
# ...

# %%
words={}
words_unclean={}
for file in os.listdir("resource"):
    with open (f"resource/{file}","r") as f:
        words[file.split(".")[0]]=f.read().replace(","," ").replace("!"," ").replace("."," ").replace("/"," ").replace(":"," ").replace('"'," ").replace("?"," ").replace("("," ").replace(")"," ").replace("“"," ").replace("’"," ").split(" ")
        words_unclean[file.split(".")[0]]=f.read().replace(","," ").replace("/"," ").replace(":"," ").replace('"'," ").replace("?"," ").replace("("," ").replace(")"," ").replace("“"," ").replace("’"," ").split(".")

words
# Out:
# {'blackassign0001': ['Rising',
#   'IT',
#   'cities',
#   'and',
#   'its',
#   'impact',
#   'on',
#   'the',
#   'economy',
#   '',
#   'environment',
#   '',
#   'infrastructure',
#   '',
#   'and',
#   'city',
#   'life',
#   'by',
#   'the',
#   'year',
#   '2040',
#   'We',
#   'have',
#   'seen',
#   'a',
#   'huge',
#   'development',
#   'and',
#   'dependence',
#   'of',
#   'people',
#   'on',
#   'technology',
#   'in',
#   'recent',
#   'years',
#   '',
#   'We',
#   'have',
#   'also',
#   'seen',
#   'the',
#   'development',
#   'of',
#   'AI',
#   'and',
#   'ChatGPT',
#   'in',
#   'recent',
#   'years',
#   '',
#   'So',
#   'it',
#   'is',
#   'a',
#   'normal',
#   'thing',
#   'that',
#   'we',
#   'will',
#   'become',
#   'fully',
#   'dependent',
#   'on',
#   'technology',
#   'by',
#   '2040',
#   '',
#   'Information',
#   'technology',
#   'will',
#   'be',
#   'a',
#   'major',
#   'power',
#   'for',
#   'all',
#   'the',
#   'developing',
# ...

# %%
new_stop_words.append("")
for i,j in words.items():
    temp=[]
    for k in j:
        if k not in new_stop_words:
            temp.append(k)
    words[i]=temp

words
# Out:
# {'blackassign0001': ['Rising',
#   'cities',
#   'impact',
#   'economy',
#   'environment',
#   'infrastructure',
#   'city',
#   'life',
#   'year',
#   '2040',
#   'We',
#   'huge',
#   'development',
#   'dependence',
#   'people',
#   'technology',
#   'recent',
#   'years',
#   'We',
#   'development',
#   'ChatGPT',
#   'recent',
#   'years',
#   'So',
#   'normal',
#   'thing',
#   'fully',
#   'dependent',
#   'technology',
#   '2040',
#   'Information',
#   'technology',
#   'major',
#   'power',
#   'developing',
#   'nations',
#   'As',
#   'member',
#   'developing',
#   'nation',
#   'rapidly',
#   'growing',
#   'base',
#   'It',
#   'grown',
#   'cities',
#   'major',
#   'control',
#   'centres',
#   'Information',
#   'technology',
#   '2040',
#   'Rising',
#   'cities',
#   'Noida',
#   '-',
#   'Noida',
#   'Uttar',
#   'Pradesh',
#   'Delhi',
#   'emerging',
#   'sector',
#   'Many',
#   'large',
#   'companies',
#   'Google',
#   'Microsoft',
#   'IBM',
# ...

# %%
score={}
for i,j in words.items():
    pos=0
    neg=0
    for k in j:
        if k in poitivewords:
            pos+=1
        elif k in negativewords:
            neg+=1

    score[i]={"Positive Score":pos, "Negative Score":neg}

score
# Out:
# {'blackassign0001': {'Positive Score': 33, 'Negative Score': 5},
#  'blackassign0002': {'Positive Score': 58, 'Negative Score': 31},
#  'blackassign0003': {'Positive Score': 37, 'Negative Score': 23},
#  'blackassign0004': {'Positive Score': 36, 'Negative Score': 71},
#  'blackassign0005': {'Positive Score': 21, 'Negative Score': 8},
#  'blackassign0006': {'Positive Score': 84, 'Negative Score': 24},
#  'blackassign0007': {'Positive Score': 31, 'Negative Score': 59},
#  'blackassign0008': {'Positive Score': 27, 'Negative Score': 9},
#  'blackassign0009': {'Positive Score': 35, 'Negative Score': 49},
#  'blackassign0010': {'Positive Score': 135, 'Negative Score': 174},
#  'blackassign0011': {'Positive Score': 60, 'Negative Score': 19},
#  'blackassign0012': {'Positive Score': 77, 'Negative Score': 24},
#  'blackassign0013': {'Positive Score': 38, 'Negative Score': 13},
#  'blackassign0014': {'Positive Score': 19, 'Negative Score': 27},
# ...

# %%
#Polarity Score = (Positive Score – Negative Score)/ ((Positive Score + Negative Score) + 0.000001)
#Subjectivity Score = (Positive Score + Negative Score)/ ((Total Words after cleaning) + 0.000001)
#Average Sentence Length = the number of words / the number of sentences
#Percentage of Complex words = the number of complex words / the number of words 
#Fog Index = 0.4 * (Average Sentence Length + Percentage of Complex words)
#Average Number of Words Per Sentence = the total number of words / the total number of sentences

for i,j in score.items():
    score[i]["Polarity Score"] = (j["Positive Score"] - j["Negative Score"]) / ((j["Positive Score"] + j["Negative Score"]) + 0.000001)

    score[i]["Subjectivity Score"] = (j["Positive Score"] + j["Negative Score"]) / ( len(words[i]) + 0.000001)

    score[i]["Average Sentence Length"] = len(words[i]) / len(words_unclean[i])

    complex_words=0
    total_syllables=0
    for x in words[i]:
        syllables=0
        for y in x:
            if y in ["a","e","i","o","u","A","E","I","O","U"]:
                syllables+=1
        if x[-2:] in ["es","ed"]:
            syllables-=1

        total_syllables += syllables

        if syllables>2 :
            complex_words+=1

    score[i]["Percentage of Complex words"] = complex_words / len(words[i])

    score[i]["Fog Index"] = 0.4 * ( score[i]["Average Sentence Length"] + score[i]["Percentage of Complex words"])

    #score[i]["Average Number of Words Per Sentence"] = 

    score[i]["Complex word count"]= complex_words

    score[i]["Word count"] = len(words[i])

    score[i]["Syllables per word"] = total_syllables / len(words[i])

    character=0
    for z in words[i]:
        character+=len(z)
        

    score[i]["Average Word Length"] = character / len(words[i])





score
# Out:
# {'blackassign0001': {'Positive Score': 33,
#   'Negative Score': 5,
#   'Polarity Score': 0.7368420858725767,
#   'Subjectivity Score': 0.05873261196486459,
#   'Average Sentence Length': 647.0,
#   'Percentage of Complex words': 0.3415765069551777,
#   'Fog Index': 258.9366306027821,
#   'Complex word count': 221,
#   'Word count': 647,
#   'Syllables per word': 2.160741885625966,
#   'Personal Pronouns': 0},
#  'blackassign0002': {'Positive Score': 58,
#   'Negative Score': 31,
#   'Polarity Score': 0.30337078310819343,
#   'Subjectivity Score': 0.10893512838563632,
#   'Average Sentence Length': 817.0,
#   'Percentage of Complex words': 0.4908200734394125,
#   'Fog Index': 326.9963280293758,
#   'Complex word count': 401,
#   'Word count': 817,
#   'Syllables per word': 2.648714810281518,
#   'Personal Pronouns': 0},
#  'blackassign0003': {'Positive Score': 37,
#   'Negative Score': 23,
#   'Polarity Score': 0.23333332944444451,
#   'Subjectivity Score': 0.08823529398788928,
# ...
